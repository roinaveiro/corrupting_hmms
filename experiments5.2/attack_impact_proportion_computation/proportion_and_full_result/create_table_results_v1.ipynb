# %%
from create_table_results_func import *

# %%
load_imp_df(exp = '2', attacker = 'attr', comb_num = '4')
load_comp_df(exp = '3')

# %%
hyp_D
# Out:
# {'2': {'attr': {'1': {'SA': 'E', 'MCTS': 'C'},
#    '2': {'SA': 'A', 'MCTS': 'C'},
#    '3': {'SA': 'B', 'MCTS': 'E'},
#    '4': {'SA': 'A', 'MCTS': 'E'}},
#   'rep': {'1': {'SA': 'B', 'MCTS': 'E'},
#    '2': {'SA': 'B', 'MCTS': 'E'},
#    '3': {'SA': 'B', 'MCTS': 'E'},
#    '4': {'SA': 'B', 'MCTS': 'E'}},
#   'dd': {'1': {'SA': 'B', 'MCTS': 'E'},
#    '2': {'SA': 'B', 'MCTS': 'B'},
#    '3': {'SA': 'B', 'MCTS': 'E'},
#    '4': {'SA': 'B', 'MCTS': 'B'}},
#   'pd': {'1': {'SA': 'D', 'MCTS': 'B'},
#    '2': {'SA': 'D', 'MCTS': 'B'},
#    '3': {'SA': 'D', 'MCTS': 'A'},
#    '4': {'SA': 'D', 'MCTS': 'A'}}},
#  '3': {'attr': {'1': {'SA': 'B', 'MCTS': 'B'},
#    '2': {'SA': 'A', 'MCTS': 'C'},
#    '3': {'SA': 'B', 'MCTS': 'B'},
#    '4': {'SA': 'B', 'MCTS': 'B'}},
#   'rep': {'1': {'SA': 'B', 'MCTS': 'B'},
#    '2': {'SA': 'A', 'MCTS': 'C'},
#    '3': {'SA': 'B', 'MCTS': 'B'},
#    '4': {'SA': 'E', 'MCTS': 'B'}},
#   'dd': {'1': {'SA': 'B', 'MCTS': 'B'},
# ...

# %%
for e in ['2','3']:
    for a in ['attr', 'rep', 'dd', 'pd']:
        create_full_result(e, a).to_csv('full_results/exp_'+e+'_attacker_'+ a+'_.csv',index=False)

# %%
os.listdir('full_results/')
