# %%
import pickle
import os

import numpy as np
import pandas as pd

# %%
fnames = os.listdir("results/w1_1.0_w2_5.0_sentence_34043_1000/")
x = []
for name in fnames:
    full_name = f'results/w1_1.0_w2_5.0_sentence_34043_1000/{name}'
    with open(full_name, 'rb') as f:
        x.append(pickle.load(f))

df = pd.DataFrame(x)

# %%
df
# Out:
#    n_exp   w1   w2     k_value  rho  n_obs  n_hidden   T  \
# 0      0  1.0  5.0  10000000.0  1.0    300        29  31
# 1      1  1.0  5.0  10000000.0  1.0    300        29  31
# 2      2  1.0  5.0  10000000.0  1.0    300        29  31
# 3      3  1.0  5.0  10000000.0  1.0    300        29  31
# 4      4  1.0  5.0  10000000.0  1.0    300        29  31
# 5      5  1.0  5.0  10000000.0  1.0    300        29  31
# 6      6  1.0  5.0  10000000.0  1.0    300        29  31
# 7      7  1.0  5.0  10000000.0  1.0    300        29  31
# 8      8  1.0  5.0  10000000.0  1.0    300        29  31
# 9      9  1.0  5.0  10000000.0  1.0    300        29  31
#
#                                      original_phrase  \
# 0  [wednesday, ,, u.s., military, said, iraqi, am...
# 1  [wednesday, ,, u.s., military, said, iraqi, am...
# 2  [wednesday, ,, u.s., military, said, iraqi, am...
# 3  [wednesday, ,, u.s., military, said, iraqi, am...
# 4  [wednesday, ,, u.s., military, said, iraqi, am...
# ...

# %%
print(" ".join(x[-1]["attacked_phrase"]))
# Out:
# last , u.s. reports members trade foreign troops countries least leaders detained fighting city 's region , told used , u.s. israeli city elections detained 10 reported men weapons friday used

# %%
print(" ".join(x[-1]["original_phrase"]))
# Out:
# wednesday , u.s. military said iraqi american troops killed least insurgents detained fighting city 's region , another baghdad , u.s. military says troops detained 10 reported men weapons car .
