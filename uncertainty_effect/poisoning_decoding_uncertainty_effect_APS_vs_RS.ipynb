# %%
from viz_func_APS_vs_RS import *

# %%
color_params_APS={"color_mean": "red", "color_std": "darkred", "color_sh": "lightsalmon"}
color_params_RS = {'color_mean':"blue", 'color_std':'darkblue',"color_sh":"lightblue"}

# %%
os.listdir('unc_str_results_all/APS/pd_att')
# Out:
# ['unc_structure_comb_1__APS_pd_Q_20_X_20_T_20_rho_0.95_k_10000_all.json',
#  'unc_structure_comb_2__APS_pd_Q_20_X_20_T_20_rho_0.95_k_100_all.json',
#  'unc_structure_comb_3__APS_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
#  'unc_structure_comb_4__APS_pd_Q_20_X_20_T_20_rho_0.75_k_100_all.json']

# %% [markdown]
# ### Combination 1: rho = 0.95, k =10000

# %%
APS_df = pd.read_json('unc_str_results_all/APS/pd_att/unc_structure_comb_1__APS_pd_Q_20_X_20_T_20_rho_0.95_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('unc_str_results_all/RS/pd_att/unc_structure_comb_1__RS_pd_Q_20_X_20_T_20_rho_0.95_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combination 2: rho =0.95, k = 100

# %%
APS_df = pd.read_json('unc_str_results_all/APS/pd_att/unc_structure_comb_2__APS_pd_Q_20_X_20_T_20_rho_0.95_k_100_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('unc_str_results_all/RS/pd_att/unc_structure_comb_2__RS_pd_Q_20_X_20_T_20_rho_0.95_k_100_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combiantion 3: rho =0.75, k = 10000

# %%
APS_df = pd.read_json('unc_str_results_all/APS/pd_att/unc_structure_comb_3__APS_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('unc_str_results_all/RS/pd_att/unc_structure_comb_3__RS_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combination 4: rho = 0.75, k = 100

# %%
APS_df = pd.read_json('unc_str_results_all/APS/pd_att/unc_structure_comb_4__APS_pd_Q_20_X_20_T_20_rho_0.75_k_100_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('unc_str_results_all/RS/pd_att/unc_structure_comb_4__RS_pd_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)
