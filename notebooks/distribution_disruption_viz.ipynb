# %%
from hmm_utils import HMM
from distribution_disruption_save_results_utils import *
from distribution_disruption_viz_utils import * 
from params import *

# %%
hmm = HMM(n_components=3, n_obs=6 )
hmm.emissionprob_ = hmm_params['emission']
hmm.transmat_     = hmm_params['transition']
hmm.startprob_    = hmm_params['priors']

# %%
dd_ratio_df = pd.read_csv('results/distribution_disruption_ratio.csv')
dd_contour_df = pd.read_csv('results/distribution_disruption_contour.csv')
dd_box_df = pd.read_csv('results/distribution_disruption_box.csv')
dd_info_df = pd.read_csv('results/distribution_disruption_info.csv')

# %%
df_dict = {'ratio':dd_ratio_df,
          'contour':dd_contour_df,
            'box':dd_box_df,
             'info':dd_info_df}

viz_d = df_to_viz_d(df_dict)

# %%
viz_grid(viz_d, params_d ={'fig_size':(12.5,9.75),
                               'title_size':20}, save = False, dir2save = None)
