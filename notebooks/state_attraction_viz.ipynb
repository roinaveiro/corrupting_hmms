# %%
from hmm_utils import HMM
from state_attraction_repulsion_save_results_utils import *
from state_attraction_repulsion_viz_utils import * 
from params_attraction import *

# %%
hmm = HMM(n_components=3, n_obs=6 )
hmm.emissionprob_ = hmm_params['emission']
hmm.transmat_     = hmm_params['transition']
hmm.startprob_    = hmm_params['priors']

# %%
sattr_ratio_df = pd.read_csv('results/attraction/state_attraction_ratio.csv')
sattr_contour_df = pd.read_csv('results/attraction/state_attraction_contour.csv')
sattr_box_df = pd.read_csv('results/attraction/state_attraction_box.csv')
sattr_info_df = pd.read_csv('results/attraction/state_attraction_info.csv')

# %%
df_dict = {'ratio':sattr_ratio_df,
          'contour':sattr_contour_df,
            'box':sattr_box_df,
             'info':sattr_info_df}

viz_d = df_to_viz_d(df_dict)

# %%
viz_grid(viz_d, params_d ={'fig_size':(12.5,9.75),
                               'title_size':20}, save = False, dir2save = None)
