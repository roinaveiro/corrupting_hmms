# %%
from hmm_utils import HMM
from poisoning_decoding_save_results_utils import *
from poisoning_decoding_viz_utils import * 
from params import *

# %%
hmm = HMM(n_components=3, n_obs=6 )
hmm.emissionprob_ = hmm_params['emission']
hmm.transmat_     = hmm_params['transition']
hmm.startprob_    = hmm_params['priors']

# %%
pdec_ratio_df = pd.read_csv('results/poisoning_decoding_ratio.csv')
pdec_contour_df = pd.read_csv('results/poisoning_decoding_contour.csv')
pdec_box_df = pd.read_csv('results/poisoning_decoding_box.csv')
pdec_info_df = pd.read_csv('results/poisoning_decoding_info.csv')

# %%
df_dict = {'ratio':pdec_ratio_df,
          'contour':pdec_contour_df,
            'box':pdec_box_df}

viz_d = df_to_viz_d(df_dict)

# %%
viz_grid(viz_d, params_d ={'fig_size':(11.5,8.25),'title_size':20})

# %%
22/27
# Out:
# 0.8148148148148148
