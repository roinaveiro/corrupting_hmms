# %%
import os
import pandas as pd
from viz_func_APS_vs_RS_1 import *

# %%
os.listdir('experiment_3/SA/rep/64_64_lr_0005')
# Out:
# ['HMM_structure_comb_1__SA_rep_Q_30_X_30_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_2__SA_rep_Q_10_X_10_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_3__SA_rep_Q_10_X_30_T_10_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json']

# %%
color_params_red ={"color_mean": "red", "color_std": "darkred", "color_sh": "lightsalmon"}
color_params_blue = {'color_mean':"blue", 'color_std':'darkblue',"color_sh":"lightblue"}
color_params_green = {'color_mean':'green', 'color_std': 'darkgreen', 'color_sh':'lightgreen'}
color_params_yellow = {'color_mean':'yellow', 'color_std': 'gold', 'color_sh':'lightyellow'}
color_params_purple = {'color_mean':'violet', 'color_std': 'darkviolet', 'color_sh':'orchid'}
color_params_orange = {'color_mean':'orange', 'color_std': 'darkorange', 'color_sh':'navajowhite'}
color_params_brown = {'color_mean':'chocolate', 'color_std': 'saddlebrown', 'color_sh':'sandybrown'}
dict_COLOR = {'64_64_lr_0005':color_params_red,
           '64_64_lr_01': color_params_blue,
            'A': color_params_green,
             'B': color_params_yellow,
              'C': color_params_purple,
              'D': color_params_orange}

# %%
df_64_64_lr_0005 = pd.read_json('experiment_3/SA/rep/64_64_lr_0005/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')
df_64_64_lr_01 = pd.read_json('experiment_3/SA/rep/64_64_lr_01/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')
df_A = pd.read_json('experiment_3/SA/rep/A/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')
df_B = pd.read_json('experiment_3/SA/rep/B/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')
df_C = pd.read_json('experiment_3/SA/rep/C/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')

df_D = pd.read_json('experiment_3/SA/rep/D/HMM_structure_comb_4__SA_rep_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                 orient = 'split')

dict_DF = {'64_64_lr_0005':df_64_64_lr_0005,
           '64_64_lr_01':df_64_64_lr_01,
            'A': df_A,
             'B': df_B,
              'C': df_C,
               'D': df_D}

plot_quality_vs_time_1(dict_DF, dict_COLOR,y_axis_boolean = True, y_axis_t = np.arange(17,27.5,1.5),only_mean =True)
# Out:
# ------------------- 64_64_lr_0005 -----------------------------
# Mean last time 24.10360561488
# ------------------- 64_64_lr_01 -----------------------------
# Mean last time 22.34624498526
# ------------------- A -----------------------------
# Mean last time 24.861122723949997
# ------------------- B -----------------------------
# Mean last time 24.85867417627
# ------------------- C -----------------------------
# Mean last time 24.022570320639996
# ------------------- D -----------------------------
# Mean last time 24.792360126560002

# %%
grid_solver_quality(dict_DF, dict_COLOR, y_axis_t_ = np.arange(17,27.5,1.5))
# Out:
# ------------------------------ 64_64_lr_0005 ----------------------------------
# Mean last time 24.10360561488
# ------------------------------ 64_64_lr_01 ----------------------------------
# Mean last time 22.34624498526
# ------------------------------ A ----------------------------------
# Mean last time 24.861122723949997
# ------------------------------ B ----------------------------------
# Mean last time 24.85867417627
# ------------------------------ C ----------------------------------
# Mean last time 24.022570320639996
# ------------------------------ D ----------------------------------
# Mean last time 24.792360126560002
