# %%
import os
import pandas as pd
from viz_func_APS_vs_RS_1 import *

# %%
os.listdir('experiment_2/RS/dd/64_64_lr_0005')
# Out:
# ['unc_structure_comb_1__RS_dd_Q_20_X_20_T_20_rho_0.95_k_10000_all.json',
#  'unc_structure_comb_2__RS_dd_Q_20_X_20_T_20_rho_0.95_k_100_all.json',
#  'unc_structure_comb_3__RS_dd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
#  'unc_structure_comb_4__RS_dd_Q_20_X_20_T_20_rho_0.75_k_100_all.json']

# %%
color_params_red ={"color_mean": "red", "color_std": "darkred", "color_sh": "lightsalmon"}
color_params_blue = {'color_mean':"blue", 'color_std':'darkblue',"color_sh":"lightblue"}
color_params_green = {'color_mean':'green', 'color_std': 'darkgreen', 'color_sh':'lightgreen'}
color_params_yellow = {'color_mean':'yellow', 'color_std': 'gold', 'color_sh':'lightyellow'}
color_params_purple = {'color_mean':'violet', 'color_std': 'darkviolet', 'color_sh':'orchid'}
color_params_orange = {'color_mean':'orange', 'color_std': 'darkorange', 'color_sh':'navajowhite'}
color_params_brown = {'color_mean':'chocolate', 'color_std': 'saddlebrown', 'color_sh':'sandybrown'}
dict_COLOR = {'64_64_lr_0005':color_params_red,
           '64_64_lr_01': color_params_blue,
            'A': color_params_green,
             'B': color_params_yellow,
              'C': color_params_purple,
              'D': color_params_orange}

# %%
df_64_64_lr_0005 = pd.read_json('experiment_2/SA/pd/64_64_lr_0005/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')
df_64_64_lr_01 = pd.read_json('experiment_2/SA/pd/64_64_lr_01/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')
df_A = pd.read_json('experiment_2/SA/pd/A/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')
df_B = pd.read_json('experiment_2/SA/pd/B/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')
df_C = pd.read_json('experiment_2/SA/pd/C/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')

df_D = pd.read_json('experiment_2/SA/pd/D/unc_structure_comb_3__SA_pd_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
                 orient = 'split')

dict_DF = {'64_64_lr_0005':df_64_64_lr_0005,
           '64_64_lr_01':df_64_64_lr_01,
            'A': df_A,
             'B': df_B,
              'C': df_C,
               'D': df_D}

plot_quality_vs_time_1(dict_DF, dict_COLOR,y_axis_boolean = True, y_axis_t = np.arange(55.5,75.5,1.5),only_mean =True)
# Out:
# ------------------- 64_64_lr_0005 -----------------------------
# Mean last time 64.77503059829999
# ------------------- 64_64_lr_01 -----------------------------
# Mean last time 63.15714163045
# ------------------- A -----------------------------
# Mean last time 66.44680095788999
# ------------------- B -----------------------------
# Mean last time 73.57886687122001
# ------------------- C -----------------------------
# Mean last time 66.63835754351001
# ------------------- D -----------------------------
# Mean last time 64.84609556897999

# %%
grid_solver_quality(dict_DF, dict_COLOR,  y_axis_t_ =  np.arange(55.5,75.5,1.5))
# Out:
# ------------------------------ 64_64_lr_0005 ----------------------------------
# Mean last time 64.77503059829999
# ------------------------------ 64_64_lr_01 ----------------------------------
# Mean last time 63.15714163045
# ------------------------------ A ----------------------------------
# Mean last time 66.44680095788999
# ------------------------------ B ----------------------------------
# Mean last time 73.57886687122001
# ------------------------------ C ----------------------------------
# Mean last time 66.63835754351001
# ------------------------------ D ----------------------------------
# Mean last time 64.84609556897999
