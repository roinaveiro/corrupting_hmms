# %%
import os
import pandas as pd
from viz_func_APS_vs_RS_1 import *

# %%
os.listdir('experiment_2/RS/rep/64_64_lr_0005/')
# Out:
# ['unc_structure_comb_1__RS_rep_Q_20_X_20_T_20_rho_0.95_k_10000_all.json',
#  'unc_structure_comb_2__RS_rep_Q_20_X_20_T_20_rho_0.95_k_100_all.json',
#  'unc_structure_comb_3__RS_rep_Q_20_X_20_T_20_rho_0.75_k_10000_all.json',
#  'unc_structure_comb_4__RS_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json']

# %%
color_params_red ={"color_mean": "red", "color_std": "darkred", "color_sh": "lightsalmon"}
color_params_blue = {'color_mean':"blue", 'color_std':'darkblue',"color_sh":"lightblue"}
color_params_green = {'color_mean':'green', 'color_std': 'darkgreen', 'color_sh':'lightgreen'}
color_params_yellow = {'color_mean':'yellow', 'color_std': 'gold', 'color_sh':'lightyellow'}
color_params_purple = {'color_mean':'violet', 'color_std': 'darkviolet', 'color_sh':'orchid'}
color_params_orange = {'color_mean':'orange', 'color_std': 'darkorange', 'color_sh':'navajowhite'}
color_params_brown = {'color_mean':'chocolate', 'color_std': 'saddlebrown', 'color_sh':'sandybrown'}
dict_COLOR = {'SA_B':color_params_red,
           'RS_64_64_lr_0005': color_params_blue,
            'APS_1': color_params_green,
             'APS_500': color_params_yellow,
              'RME': color_params_purple}

# %%
df_RS_64_64_lr_0005 = pd.read_json('experiment_2/RS/rep/64_64_lr_0005/unc_structure_comb_4__RS_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                 orient = 'split')
df_SA_B = pd.read_json('experiment_2/SA/rep/B/unc_structure_comb_4__SA_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                 orient = 'split')
df_APS_1 = pd.read_json('experiment_2/APS/rep/cs_1/unc_structure_comb_4__APS_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                 orient = 'split')
df_APS_500 = pd.read_json('experiment_2/APS/rep/cs_500/unc_structure_comb_4__APS_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                 orient = 'split')
df_RME = pd.read_json('experiment_2/RME/rep/unc_structure_comb_4__RME_rep_Q_20_X_20_T_20_rho_0.75_k_100_all.json',
                 orient = 'split')


dict_DF = {'SA_B':df_SA_B,
           'RS_64_64_lr_0005':df_RS_64_64_lr_0005,
            'APS_1': df_APS_1,
             'APS_500': df_APS_500,
              'RME': df_RME}

# %%
grid_solver_quality(dict_DF, dict_COLOR, y_axis_t_ = np.arange(12.5,40.5,1.5))
# Out:
# ------------------------------ SA_B ----------------------------------
# Mean last time 33.59531510153
# ------------------------------ RS_64_64_lr_0005 ----------------------------------
# Mean last time 25.50867197929
# ------------------------------ APS_1 ----------------------------------
# Mean last time 33.59371652816001
# ------------------------------ APS_500 ----------------------------------
# Mean last time 33.62288284456
# ------------------------------ RME ----------------------------------
# Mean last time 19.31332735929

# %%
plot_quality_vs_time_1(dict_DF, dict_COLOR,y_axis_boolean = True, y_axis_t = np.arange(12.5,40.5,1.5),only_mean =True)
# Out:
# ------------------- SA_B -----------------------------
# Mean last time 33.59531510153
# ------------------- RS_64_64_lr_0005 -----------------------------
# Mean last time 25.50867197929
# ------------------- APS_1 -----------------------------
# Mean last time 33.59371652816001
# ------------------- APS_500 -----------------------------
# Mean last time 33.62288284456
# ------------------- RME -----------------------------
# Mean last time 19.31332735929
