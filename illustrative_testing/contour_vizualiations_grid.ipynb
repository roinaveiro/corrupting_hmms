# %%
from viz_utils import *

# %% [markdown]
# ### STATE ATTRACTION PROBLEM

# %%
att_lu = pd.read_csv('results_csv/state_attraction_repulsion/att_low_unc_contour.csv')
att_hu = pd.read_csv('results_csv/state_attraction_repulsion/att_high_unc_contour.csv')
res_att = {'high':att_hu,'low':att_lu}

# %%
scatter_plot_grid(res_att, 'State attraction problem', 
                  save =  True,
                  dir2save = 'viz/state_attraction/contour_att_grid.png')

# %% [markdown]
# ### STATE REPULSION PROBLEM

# %%
rep_lu = pd.read_csv('results_csv/state_attraction_repulsion/rep_low_unc_contour.csv')
rep_hu = pd.read_csv('results_csv/state_attraction_repulsion/rep_high_unc_contour.csv')
res_rep = {'high':rep_hu,'low':rep_lu}

# %%
scatter_plot_grid(res_rep, 'State repulsion problem', in_params = {'label_size': 13.5,'tick_size':12,
                                                      'title_size':14.8,
                                                     'points_size': 40,
                                                        'c':-1},
                 save =  True,
                  dir2save = 'viz/state_repulsion/contour_rep_grid.png')

# %% [markdown]
# ### DISTRIBUTION DISRUPTION PROBLEM

# %%
dd_lu = pd.read_csv('results_csv/distribution_disruption/dd_low_unc_contour.csv')
dd_hu = pd.read_csv('results_csv/distribution_disruption/dd_high_unc_contour.csv')
res_dd = {'high':dd_hu,'low':dd_lu}

# %%
scatter_plot_grid(res_dd, 'Distribution disruption',  
                 color_params = {'c':1, 'min_max_0_1':False},
                 save =  True,
                dir2save = 'viz/distribution_disruption/contour_dd_grid.png')

# %% [markdown]
# ### PATH ATTRACTION PROBLEM

# %%
pd_lu = pd.read_csv('results_csv/poisoning_decoding/pd_low_unc_contour.csv')
pd_hu = pd.read_csv('results_csv/poisoning_decoding/pd_high_unc_contour.csv')
pd_lu = pd_lu[(pd_lu['w1_values']<300)&(pd_lu['w2_values']<40)]
pd_hu = pd_hu[(pd_hu['w1_values']<300)&(pd_hu['w2_values']<40)]
res_pd = {'high':pd_hu, 'low':pd_lu}

# %%
scatter_plot_grid(res_pd, 'Path attraction problem', 
                  save =  True, 
                  dir2save = 'viz/poisoning_decoding/contour_pd_grid.png')
