# %%
from viz_func_APS_vs_RS import *

# %%
color_params_APS={"color_mean": "red", "color_std": "darkred", "color_sh": "lightsalmon"}
color_params_RS = {'color_mean':"blue", 'color_std':'darkblue',"color_sh":"lightblue"}

# %%
dir_name_APS = 'HMM_structure_results_all/APS/dd_att/'
os.listdir(dir_name_APS)
# Out:
# ['HMM_structure_comb_1__APS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_2__APS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_3__APS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_4__APS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json']

# %%
dir_name_RS = 'HMM_structure_results_all/RS/dd_att/'
os.listdir(dir_name_RS)
# Out:
# ['HMM_structure_comb_1__RS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_2__RS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_3__RS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json',
#  'HMM_structure_comb_4__RS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json']

# %%
for i in os.listdir(dir_name_APS):
    dataf = pd.read_json(dir_name_APS + i, orient = 'split')
    print(i, len(dataf))
for i in os.listdir(dir_name_RS):
    dataf = pd.read_json(dir_name_RS + i, orient = 'split')
    print(i, len(dataf))
# Out:
# HMM_structure_comb_1__APS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_2__APS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_3__APS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_4__APS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_1__RS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_2__RS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_3__RS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json 800
# HMM_structure_comb_4__RS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json 800

# %% [markdown]
# ### Combination 1: |X| = 30, |T| =30, |Q| = 30

# %%
APS_df = pd.read_json('HMM_structure_results_all/APS/dd_att/HMM_structure_comb_1__APS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('HMM_structure_results_all/RS/dd_att/HMM_structure_comb_1__RS_dd_Q_30_X_30_T_30_rho_0.95_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combination 2:  |X| = 10, |T| =30, |Q| = 10

# %%
APS_df = pd.read_json('HMM_structure_results_all/APS/dd_att/HMM_structure_comb_2__APS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('HMM_structure_results_all/RS/dd_att/HMM_structure_comb_2__RS_dd_Q_10_X_10_T_30_rho_0.95_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combination 3:  |X| = 30, |T| =10, |Q| = 10

# %%
APS_df = pd.read_json('HMM_structure_results_all/APS/dd_att/HMM_structure_comb_3__APS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('HMM_structure_results_all/RS/dd_att/HMM_structure_comb_3__RS_dd_Q_10_X_30_T_10_rho_0.95_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %% [markdown]
# ### Combination 4:  |X| = 10, |T| =30, |Q| = 30

# %%
APS_df = pd.read_json('HMM_structure_results_all/APS/dd_att/HMM_structure_comb_4__APS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json'
                      ,orient = 'split')
RS_df = pd.read_json('HMM_structure_results_all/RS/dd_att/HMM_structure_comb_4__RS_dd_Q_30_X_10_T_10_rho_0.95_k_10000_all.json',
                     orient = 'split')
dict_DF = {'APS': APS_df, 'RS': RS_df}

plot_quality_one_optimizer(dict_DF['APS'],color_params_APS, single=True)
plot_quality_one_optimizer(dict_DF['RS'],color_params_RS, single=True)
plot_quality_vs_time(dict_DF)

# %%
sum(np.arange(15,1200,15))/3600
# Out:
# 13.166666666666666
